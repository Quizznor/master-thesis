# %%
from Binaries import *

Trigger = NNClassifier("test_lol", "240_CNN")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 1, 80, 4)          40
#
#  conv1d_2 (Conv1D)           (None, 1, 76, 2)          42
#
#  flatten_2 (Flatten)         (None, 152)               0
#
#  dense_4 (Dense)             (None, 10)                1530
#
#  dense_5 (Dense)             (None, 2)                 22
#
# ...
# Total params: 1,634
# Trainable params: 1,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
Events = EventGenerator("all", sliding_window_length = 40, real_background = True, apply_downsampling = True)
Trigger.train(Events, 1, verbose = 1)
# Out:
# [INFO] -- LOADING LO_QUI_DON: randoms0183.csv
# [INFO] -- LOADING NURIA: randoms0317.csv
# [INFO] -- LOADING LO_QUI_DON: randoms3991.csv
#   135/26566 [..............................] - ETA: 1:40:37 - loss: 0.2170 - accuracy: 0.9491
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 Events = EventGenerator("all", sliding_window_length = 40, real_background = True, apply_downsampling = True)
# ----> 2 Trigger.train(Events, 1, verbose = 1)
#
# File ~/Binaries/Network.py:256, in NNClassifier.train(self, Datasets, epochs, **kwargs)
#     251 # print("Creating physics information for both datasets...")
#     252 # TrainingSet.physics_test(n_showers = int(0.05 * TrainingSet.__len__()), save_dir = f"/cr/data01/filip/models/{self.name}/training_set_physics_test.png")
# ...
