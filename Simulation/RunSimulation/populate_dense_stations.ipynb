# %%
test_str = \
f'\t<denseStation id="{id}">\n\
\t\t<deltaPhi unit="radian"> 5.75959 </deltaPhi>\n\
\t\t<r unit="meter"> 1000 </r>\n\
\t</denseStation>'

# %%
print(test_str)
# Out:
# 	<denseStation id="90011">
# 		<deltaPhi unit="radian"> 5.75959 </deltaPhi>
# 		<r unit="meter"> 1000 </r>
# 	</denseStation>

# %%
import matplotlib.pyplot as plt
import numpy as np

spd = list(np.arange(100, 1500, 100)) + list(np.arange(1500, 2100, 200)) + list(np.arange(2100, 3001, 300)) #+ list(np.arange(3000, 6001, 500))

for spd_bin in spd:

    n_dense_stations = int(spd_bin/1000 * 12)
    theta = np.linspace(0, 2 * np.pi, n_dense_stations)

    for i in range(n_dense_stations):
        id = "9" + str(spd_bin // 100).zfill(2) + str(i).zfill(2)
        print(id)

    plt.scatter(spd_bin * np.cos(theta), spd_bin * np.sin(theta))
    plt.plot(spd_bin * np.cos(theta), spd_bin * np.sin(theta))

plt.scatter(0, 0, c = "k", s = 500)
plt.rcParams["figure.figsize"] = [30, 30]
# plt.aspect('equal')
# Out:
# 90100
# 90200
# 90201
# 90300
# 90301
# 90302
# 90400
# 90401
# 90402
# 90403
# 90500
# 90501
# 90502
# 90503
# 90504
# 90505
# 90600
# 90601
# 90602
# 90603
# 90604
# 90605
# 90606
# 90700
# 90701
# 90702
# 90703
# 90704
# 90705
# 90706
# 90707
# 90800
# 90801
# 90802
# 90803
# 90804
# 90805
# 90806
# 90807
# 90808
# 90900
# 90901
# 90902
# 90903
# 90904
# 90905
# 90906
# 90907
# 90908
# 90909
# 91000
# 91001
# 91002
# 91003
# 91004
# 91005
# 91006
# 91007
# 91008
# 91009
# 91010
# 91011
# 91100
# 91101
# 91102
# 91103
# 91104
# 91105
# 91106
# 91107
# 91108
# 91109
# 91110
# 91111
# 91112
# 91200
# 91201
# 91202
# 91203
# 91204
# 91205
# 91206
# 91207
# 91208
# 91209
# 91210
# 91211
# 91212
# 91213
# 91300
# 91301
# 91302
# 91303
# 91304
# 91305
# 91306
# 91307
# 91308
# 91309
# 91310
# 91311
# 91312
# 91313
# 91314
# 91400
# 91401
# 91402
# 91403
# 91404
# 91405
# 91406
# 91407
# 91408
# 91409
# 91410
# 91411
# 91412
# 91413
# 91414
# 91415
# 91500
# 91501
# 91502
# 91503
# 91504
# ...

# %%
26 * 12
# Out:
# 312

# %%
print(np.diff(phi))
# Out:
# [0.523599 0.523601 0.5236   0.5236   0.52359  0.5236   0.5236   0.5236
#  0.5236   0.5236   0.5236  ]

# %%
print(2 * np.pi, phi[-1] + 0.5236)
# Out:
# 6.283185307179586 6.28319

# %%
print(2*np.pi*1000/12)
# Out:
# 523.5987755982989

# %%
import matplotlib.pyplot as plt



plt.plot(spd, a)
