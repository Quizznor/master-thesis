# %%
from Binaries import *

Events = EventGenerator("/cr/tempdata01/filip/QGSJET-II/LOW_SPD/16.5_17", split = 1, real_background = False)

Events.physics_test()
# Out:
# Step 23820/23820 | 00:01:47 elapsed ||--------------------|| 100% -- 4.521 ms/step, ETA: 00:00:00
