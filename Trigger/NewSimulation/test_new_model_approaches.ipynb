# %%
from Binaries import *

Assifier = NNClassifier("120_TwoLayer_HighEnergy_NoCuts")
Assifier.spd_energy_efficiency("all_energies")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 4)          40
#
#  conv1d (Conv1D)             (None, 1, 20, 2)          18
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________
#
#
# DATASET                                                                     TP      FP      TN      FN
# 120_TwoLayer_HighEnergy_NoCuts all_energies                             340283       0       0  123493 -> ACC = 73.37%

# %%
Assifier2 = NNClassifier("360_OneLayer_FullBandwidth_NoCuts")
Assifier2.spd_energy_efficiency("validation_data")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 120, 4)         40
#
#  flatten (Flatten)           (None, 480)               0
#
#  dense (Dense)               (None, 2)                 962
#
# ...
# Total params: 1,002
# Trainable params: 1,002
# Non-trainable params: 0
# _________________________________________________________________
#
# 360_OneLayer_FullBandwidth_NoCuts validation_data                        99463       0       0  196599 -> ACC = 33.60%

# %%
Assifier3 = NNClassifier("360_TwoLayer_FullBandwidth_NoCuts")
Assifier3.spd_energy_efficiency("validation_data")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 120, 8)         80
#
#  conv1d (Conv1D)             (None, 1, 60, 4)          68
#
#  flatten (Flatten)           (None, 240)               0
#
#  dense (Dense)               (None, 2)                 482
#
# ...
# Total params: 630
# Trainable params: 630
# Non-trainable params: 0
# _________________________________________________________________
#
# 360_TwoLayer_FullBandwidth_NoCuts validation_data                        98994       0       0  175732 -> ACC = 36.03%

# %%
Assifier2.do_t3_simulation("validation_data")
# Out:
# Step 99999/100000 | 00:00:35 elapsed ||------------------- || 99% -- 0.355 ms/step, ETA: 00:00:00
# Step 100000/100000 | 00:00:35 elapsed ||--------------------|| 100% -- 0.355 ms/step, ETA: 00:00:00

# %%
Assifier3.do_t3_simulation("validation_data")
# Out:
# Step 99999/100000 | 00:00:36 elapsed ||------------------- || 99% -- 0.360 ms/step, ETA: 00:00:00
# Step 100000/100000 | 00:00:36 elapsed ||--------------------|| 100% -- 0.360 ms/step, ETA: 00:00:00
