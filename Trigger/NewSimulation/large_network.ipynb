# %%
from Binaries import *

Assifier = NNClassifier("120_LargeNetwork_HighEnergy_1Muon")
Assifier.spd_energy_efficiency("all_energies")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 60, 4)          16
#
#  conv1d (Conv1D)             (None, 1, 20, 8)          104
#
#  conv1d_1 (Conv1D)           (None, 1, 6, 16)          400
#
#  conv1d_2 (Conv1D)           (None, 1, 2, 4)           196
#
#  flatten (Flatten)           (None, 8)                 0
#
#  dense (Dense)               (None, 2)                 18
#
# ...
# Total params: 734
# Trainable params: 734
# Non-trainable params: 0
# _________________________________________________________________
#
#
# DATASET                                                                     TP      FP      TN      FN
# 120_LargeNetwork_HighEnergy_1Muon all_energies                          280939       0       0 1856322 -> ACC = 13.14%

# %%
Assifier.spd_energy_efficiency("validation_data")
# Out:
# 120_LargeNetwork_HighEnergy_1Muon validation_data                        22335   10906  146790   54494 -> ACC = 72.11%
