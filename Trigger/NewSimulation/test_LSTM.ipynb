# %%
from Binaries import *

# %%
LSTM = NNClassifier("120_LSTM_SingleLayer_FullBandwidth_1Muon")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 120, 1)]  0           []
#
#  lambda (Lambda)                [(None, 120, 1),     0           ['input_1[0][0]']
#                                  (None, 120, 1),
#                                  (None, 120, 1)]
#
#  lstm (LSTM)                    (None, 1)            12          ['lambda[0][0]',
#                                                                   'lambda[0][1]',
#                                                                   'lambda[0][2]']
#
#  lambda_1 (Lambda)              (None, 3, 1)         0           ['lstm[0][0]',
#                                                                   'lstm[1][0]',
#                                                                   'lstm[2][0]']
#
#  flatten (Flatten)              (None, 3)            0           ['lambda_1[0][0]']
#
#  dense (Dense)                  (None, 2)            8           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
LSTM.spd_energy_efficiency("validation_data")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# 120_LSTM_SingleLayer_FullBandwidth_1Muon      validation_data                       19261   13095  196344   43715 -> ACC =  79.15%

# %%
LSTM = NNClassifier("120_LSTM_DistinctLayers_FullBandwidth_1Muon")
LSTM.spd_energy_efficiency("validation_data")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 120, 1)]  0           []
#
#  lambda (Lambda)                [(None, 120, 1),     0           ['input_1[0][0]']
#                                  (None, 120, 1),
#                                  (None, 120, 1)]
#
#  lstm (LSTM)                    (None, 1)            12          ['lambda[0][0]']
#
#  lstm_1 (LSTM)                  (None, 1)            12          ['lambda[0][1]']
#
#  lstm_2 (LSTM)                  (None, 1)            12          ['lambda[0][2]']
#
#  lambda_1 (Lambda)              (None, 3, 1)         0           ['lstm[0][0]',
#                                                                   'lstm_1[0][0]',
#                                                                   'lstm_2[0][0]']
#
#  flatten (Flatten)              (None, 3)            0           ['lambda_1[0][0]']
#
#  dense (Dense)                  (None, 2)            8           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 44
# Trainable params: 44
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# 120_LSTM_DistinctLayers_FullBandwidth_1Muon   validation_data                       19787   16041  141300   24781 -> ACC =  79.78%
