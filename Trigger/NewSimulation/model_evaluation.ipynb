# %%
from Binaries import *

NoCuts = NNClassifier("120_OneLayer_FullBandwidth_NoCuts")

NoCuts.production_test()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 1)          10
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 92
# Trainable params: 92
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [INFO] -- LOADING NURIA: randoms0316.csv
# Step 4999/10000 | 00:23:45 elapsed ||---------           || 49% -- 285.205 ms/step, ETA: 00:23:46
# [INFO] -- LOADING NURIA: randoms0131.csv
# Step 9997/10000 | 00:45:17 elapsed ||------------------- || 99% -- 271.848 ms/step, ETA: 00:00:01
# [INFO] -- LOADING NURIA: randoms0659.csv
# Step 10000/10000 | 00:45:32 elapsed ||--------------------|| 100% -- 273.214 ms/step, ETA: 00:00:00
#
#
# Production test results:
#
# random traces injected: 10000
# ...

# %%
NoCuts.spd_energy_efficiency("validation_data")
# Out:
# DATASET                                                                     TP      FP      TN      FN
# 120_OneLayer_FullBandwidth_NoCuts validation_data                        99079       0       0   27429 -> ACC = 78.32%

# %%
NoCuts.do_t3_simulation("validation_data")
# Out:
# Step 504/100000 | 00:00:00 elapsed ||                    || 0% -- 0.398 ms/step, ETA: 00:00:39
# /cr/users/filip/Binaries/__config__.py:65: RuntimeWarning: overflow encountered in exp
#   return efficiency * (1 - 1 / (1 + np.exp(-scale * (x - p50))))
# Step 100000/100000 | 00:00:36 elapsed ||--------------------|| 100% -- 0.363 ms/step, ETA: 00:00:00

# %%
from Binaries import *

NoCuts = NNClassifier("120_OneLayer_FullBandwidth_NoCuts")

NoCuts.signal_efficiency("validation_data", bins = 20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 1)          10
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 92
# Trainable params: 92
# Non-trainable params: 0
# _________________________________________________________________
#
#
# DATASET                                                                     TP      FP      TN      FN
# 120_OneLayer_FullBandwidth_NoCuts validation_data                        99079       0       0   27429 -> ACC = 78.32%

# %%
AllEvents = EventGenerator("all", split = 1)
NoCuts.make_signal_dataset(AllEvents, "full_scale")
# Out:
# [INFO] -- LOADING NURIA: randoms0085.csv
# Step 698/66638 | 00:00:42 elapsed ||                    || 1% -- 61.073 ms/step, ETA: 01:07:07
# [INFO] -- LOADING NURIA: randoms0201.csv
# Step 1402/66638 | 00:01:38 elapsed ||                    || 2% -- 70.495 ms/step, ETA: 01:16:38
# [INFO] -- LOADING NURIA: randoms0777.csv
# Step 2076/66638 | 00:02:34 elapsed ||                    || 3% -- 74.495 ms/step, ETA: 01:20:09
# [INFO] -- LOADING NURIA: randoms0194.csv
# Step 2754/66638 | 00:03:30 elapsed ||                    || 4% -- 76.266 ms/step, ETA: 01:21:12
# [INFO] -- LOADING NURIA: randoms0399.csv
# Step 3406/66638 | 00:04:25 elapsed ||-                   || 5% -- 77.968 ms/step, ETA: 01:22:10
# [INFO] -- LOADING NURIA: randoms0471.csv
# Step 4100/66638 | 00:05:21 elapsed ||-                   || 6% -- 78.327 ms/step, ETA: 01:21:38
# [INFO] -- LOADING NURIA: randoms0655.csv
# Step 4751/66638 | 00:06:17 elapsed ||-                   || 7% -- 79.365 ms/step, ETA: 01:21:51
# ...

# %%
NoCuts.signal_efficiency("full_scale")
# Out:
# 120_OneLayer_FullBandwidth_NoCuts full_scale                            497852       0       0  134499 -> ACC = 78.73%

# %%
from Binaries import *

ParticleCut = NNClassifier("120_OneLayer_FullBandwidth_1Particle")
ParticleCut.spd_energy_efficiency("validation_data")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 1)          10
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 92
# Trainable params: 92
# Non-trainable params: 0
# _________________________________________________________________
#
#
# DATASET                                                                     TP      FP      TN      FN
# 120_OneLayer_FullBandwidth_1Particle validation_data                         0       0 1808062   97406 -> ACC = 94.89%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /cr/users/filip/Trigger/NewSimulation/model_evaluation.ipynb Cell 7 in <cell line: 4>()
# ...
