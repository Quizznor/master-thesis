# %%
from Binaries import *

Hardware = HardwareClassifier()

# %%
Hardware.spd_energy_efficiency("fullscale_random_traces_downsampled")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# HardwareClassifier                            fullscale_random_traces_downsampled  176506       0       0 1826518 -> ACC =   8.81%

# %%
Hardware.spd_energy_efficiency("random_traces_downsampled_scaled")
# Out:
# HardwareClassifier                            random_traces_downsampled_scaled     183872       0       0 1768383 -> ACC =   9.42%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /cr/users/filip/Trigger/NewSimulation/compare_scaling_performance.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/NewSimulation/compare_scaling_performance.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> Hardware.spd_energy_efficiency("random_traces_downsampled_scaled")
#
# File ~/Binaries/Classifier.py:374, in Classifier.spd_energy_efficiency(self, dataset, **kwargs)
#     372 # perform fit with x_err and y_err
#     373 if kwargs.get("perform_fit", True):
# --> 374     popt, pcov = curve_fit(station_hit_probability, bin_center, efficiency,
# ...
