# %%
from Binaries import *

Hardware = HardwareClassifier()

# %% [markdown]
# # UNSCALED (AS IS PERFORMANCE)

# %%
Hardware.spd_energy_efficiency("full_random_traces_downsampled_unscaled")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# HardwareClassifier                            full_random_traces_downsampled_unscaled  176394       0       0 1827324 -> ACC =   8.80%

# %% [markdown]
# # SCALED (MAYBE SHOULD BE PERFORMANCE?)

# %%
Hardware.spd_energy_efficiency("full_random_traces_downsampled_scaled")
# Out:
# HardwareClassifier                            full_random_traces_downsampled_scaled  183885       0       0 1768269 -> ACC =   9.42%

# %% [markdown]
# # SUPER HIGH SCALE (scaling factor = 0.5)

# %%
Hardware.spd_energy_efficiency("full_random_traces_downsampled_high_scale")
# Out:
# HardwareClassifier                            full_random_traces_downsampled_high_scale  220603       0       0 1504367 -> ACC =  12.79%
