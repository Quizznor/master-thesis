# %%
from Binaries import *

# %%
AllEvents = NNClassifier("120_TwoLayer_FullBandwidth_NoCuts")
AllEvents.spd_energy_efficiency("validation_data")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 4)          40
#
#  conv1d (Conv1D)             (None, 1, 20, 2)          18
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________
#
#
# DATASET                                                                     TP      FP      TN      FN
# 120_TwoLayer_FullBandwidth_NoCuts validation_data                        83858       0       0   17609 -> ACC = 82.65%

# %%
AllEvents = NNClassifier("120_TwoLayer_HighEnergy_NoCuts")
AllEvents.spd_energy_efficiency("all_energies")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 4)          40
#
#  conv1d (Conv1D)             (None, 1, 20, 2)          18
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________
#
# 120_TwoLayer_HighEnergy_NoCuts all_energies                             340283       0       0  123493 -> ACC = 73.37%
