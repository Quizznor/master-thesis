# %%
from Binaries import *

# %%
Plot = MoneyPlot("Kernel shit")

Plot.add("120_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "steelblue", label = "Kernel size $(3, 3)$")
Plot.add("120_k10CNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "orange", label = "Kernel size $(3, 10)$")
Plot.add("120_k30CNN_Downsampled_AllEnergies_5_0VEM",  color = "green", label = "Kernel size $(3, 30)$")
# Out:
# Crunching numbers for 120_eCNN_Downsampled_AllEnergies_5_0VEM: validation_data_no_cuts...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Binaries/Testing.py:80, in MoneyPlot.add(self, ensemble, dataset, **kwargs)
#      79 try:
# ---> 80     acc, acc_err, rate, rate_err, true_acc = np.loadtxt(f"/cr/users/filip/MoneyPlot/data/{ensemble}/{dataset}.csv", unpack = True)
#      82     if len(acc) != 10: print(f"[WARN] -- Incomplete predictions for {ensemble}: {dataset}... You may want to recalculate this")
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1336     delimiter = delimiter.decode('latin1')
# -> 1338 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...
