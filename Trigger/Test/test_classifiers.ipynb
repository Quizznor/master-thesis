# %%
from TriggerStudyBinaries_v7 import *
# Out:
# 2022-09-01 10:11:15.686052: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-01 10:11:15.686071: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
HardwareTriggers = HardwareClassifier()
HardwareTriggers.production_test(100000, apply_downsampling = True)

# perhaps this is caused by missing downsampling of trace?
# Also, what is the 'veto' after a trigger was issued?
# Out:
# 0.00% - 10483.39ms/batch, ETA = 104834s
# 0.01% - 5295.41ms/batch, ETA = 52949s
# 0.02% - 3565.09ms/batch, ETA = 35644s
# 0.03% - 2700.53ms/batch, ETA = 26997s
# 0.04% - 2181.61ms/batch, ETA = 21807s
# 0.05% - 1839.16ms/batch, ETA = 18382s
# 0.06% - 1593.65ms/batch, ETA = 15927s
# 0.07% - 1409.42ms/batch, ETA = 14084s
# 0.08% - 1266.27ms/batch, ETA = 12653s
# 0.09% - 1149.92ms/batch, ETA = 11489s
# 0.10% - 1055.14ms/batch, ETA = 10541s
# 0.11% - 975.71ms/batch, ETA = 9746s
# 0.12% - 908.21ms/batch, ETA = 9071s
# 0.13% - 850.27ms/batch, ETA = 8492s
# 0.14% - 799.96ms/batch, ETA = 7988s
# 0.15% - 756.73ms/batch, ETA = 7556s
# 0.16% - 718.55ms/batch, ETA = 7174s
# 0.17% - 684.51ms/batch, ETA = 6833s
# 0.18% - 653.91ms/batch, ETA = 6527s
# 0.19% - 626.48ms/batch, ETA = 6253s
# 0.20% - 601.96ms/batch, ETA = 6008s
# 0.21% - 579.31ms/batch, ETA = 5781s
# 0.22% - 558.82ms/batch, ETA = 5576s
# 0.23% - 540.04ms/batch, ETA = 5388s
# 0.24% - 522.71ms/batch, ETA = 5215s
# ...

# %%
Test_NN_no_cut = NNClassifier("minimal_conv2d_cut_0.00VEM/model_converged")
Test_NN_no_cut.production_test(10000, apply_downsampling = True)

# %%
Test_NN_higher_cut = NNClassifier("minimal_conv2d_cut_10.0VEM/model_converged")
Test_NN_higher_cut.production_test(10000)
