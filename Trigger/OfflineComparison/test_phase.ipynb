# %%
from Binaries import *

Trigger = HardwareClassifier()

# %%
Trigger.spd_energy_efficiency("q_peak_compatibility")
Trigger.spd_energy_efficiency("compatibility_all_phases")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# HardwareClassifier                            q_peak_compatibility                  66548       0       0  100822 -> ACC =  39.76%
# HardwareClassifier                            compatibility_all_phases              22432       0       0   34388 -> ACC =  39.48%
