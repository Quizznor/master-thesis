# %%
from Binaries import *

# %%
Plot = MoneyPlot("")

Plot.add("40_eCNN_Downsampled_AllEnergies_2_7VEM", "validation_data_no_cuts", color = "steelblue", label = "40 bins")
Plot.add("60_eCNN_Downsampled_AllEnergies_4_0VEM", "validation_data_no_cuts", color = "orange", label = "60 bins")
# Plot.add("90_eCNN_Downsampled_AllEnergies_6_0VEM", "validation_data_no_cuts", color = "green", label = "90 bins")
Plot.add("120_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "red", label = "120 bins")
Plot.add("240_eCNN_Downsampled_AllEnergies_8_0VEM", "validation_data_no_cuts", color = "purple", label = "240 bins")

plt.text(0.5, 0.5, "Preliminary", rotation = 20, transform = plt.gca().transAxes, color = "red", fontsize = 100, 
         verticalalignment = "center",
         horizontalalignment = "center")

Plot()

# %%
Plot = MoneyPlot("")



Plot.add("40_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "steelblue", label = "40 bins")
Plot.add("60_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "orange", label = "60 bins")
Plot.add("90_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "green", label = "90 bins")
Plot.add("120_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "red", label = "120 bins")
Plot.add("240_eCNN_Downsampled_AllEnergies_5_0VEM", "validation_data_no_cuts", color = "purple", label = "240 bins")



Plot((0.04, 0.075), (0.8, 100))

# %%
Test = Ensemble("120_TwoLayer_Downsampled_AllEnergies_NoCuts")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 4)          40
#
#  conv1d (Conv1D)             (None, 1, 20, 2)          18
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 140
# Trainable params: 140
# Non-trainable params: 0
# _________________________________________________________________
#
# ENSEMBLE_120_TwoLayer_Downsampled_AllEnergies_NoCuts: 10 models successfully initiated
