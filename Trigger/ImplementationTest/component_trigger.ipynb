# %%
from Binaries import *

# %%
ToT = HardwareClassifier(["tot"])
Th = HardwareClassifier(["th"])

# %%
start, stop = 20, 33

example_trace = np.zeros((3, 120))

# ToT Signal
example_trace[0, start:stop] += 0.3
example_trace[1, start:stop] += 0.21
example_trace[2, start:stop] += 0.1

# Th Signal
# example_trace[:, 40] = 4

print("Th :", Th(example_trace))
print("ToT:", ToT(example_trace))

plt.plot(range(120), example_trace[0])
plt.plot(range(120), example_trace[1])
plt.plot(range(120), example_trace[2])
# Out:
# Th : False
# ToT: True
