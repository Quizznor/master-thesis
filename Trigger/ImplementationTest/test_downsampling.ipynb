# %%
from Binaries import *

RawData = EventGenerator(["19_19.5"], split = 0, apply_downsampling = False, seed = 42)

Trace = RawData.__getitem__(0, full_trace = True)[0][0]

plt.ylim(-0.1, 4)
Trace.__plot__()

# %%
from Binaries import *

Downsampled = EventGenerator(["19_19.5"], split = 0, apply_downsampling = True, seed = 42)

Trace = Downsampled.__getitem__(0, full_trace = True)[0][0]

plt.ylim(-0.1, 4)
Trace.__plot__()
