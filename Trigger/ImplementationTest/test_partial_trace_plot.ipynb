# %%
from Binaries import *

# %%
Events = EventGenerator(["19_19.5"], split = 1, real_background = True, apply_downsampling = True, prior = 0)
# Out:
# [INFO] -- LOADING RANDOMS: nuria_randoms0224.csv

# %%
traces, labels = Events.__getitem__(0)

# %%
print(traces.shape)
# Out:
# (57, 3, 120)

# %%
example = traces[1]

pmt1, pmt2, pmt3 = example
x = len(pmt1)

# %%
plt.plot(range(x), pmt1, label = "PMT #1")
plt.plot(range(x), pmt2, label = "PMT #2")
plt.plot(range(x), pmt3, label = "PMT #3")

plt.ylabel(r"Signal / VEM$_\mathrm{Peak}$")
plt.xlabel("Bin / 8.33 ns")
plt.xlim(0, x)
plt.legend()
