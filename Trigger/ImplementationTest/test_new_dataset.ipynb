# %%
from Binaries import *
Test = EventGenerator(["19_19.5"], split = 1)
print(Test.__len__(), Test.files)
# Out:
# 1 ['/cr/tempdata01/filip/QGSJET-II/protons/19_19.5/DAT110304_00.csv']

# %%
traces = Test.__getitem__(0, full_trace = True)[0]
# Out:
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station
# Yield station

# %%
for i, trace in enumerate(traces):
    print(trace, end = " \t")
    print(trace.StationID, "===>", trace.n_muons, trace.n_electrons, trace.n_photons)
# Out:
# ||                                         S=====================S    || 1.5760e+19 eV @ 471 m from core    	5398 ===> 253 1417 52351
# ||          S=========S                    bb                         || 1.5760e+19 eV @ 1031 m from core    	5397 ===> 30 106 1885
# ||                                             S=========S            || 1.5760e+19 eV @ 1174 m from core    	5440 ===> 20 57 1220
# ||                         S========S                                 || 1.5760e+19 eV @ 1337 m from core    	5355 ===> 16 9 337
# ||                                             S======S               || 1.5760e+19 eV @ 1603 m from core    	5441 ===> 5 7 267
# ||          S==S                                                      || 1.5760e+19 eV @ 1826 m from core    	5356 ===> 3 3 99
# ||                               X                                    || 1.5760e+19 eV @ 3049 m from core    	5357 ===> 0 2 7
# ...

# %%
traces[1].__plot__()
