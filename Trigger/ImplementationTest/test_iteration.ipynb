# %%
from Binaries import *

# %%
TestEvents = EventGenerator(["18.5_19"], split = 1, real_background = True)

# %%
trace, _ = TestEvents.__getitem__(0, full_trace = True)
trace = trace[0]

length = trace.signal_end - trace.signal_start
plt.axvspan(trace.signal_start - 0.5 * length, trace.signal_end + 0.5 * length, alpha=0.1, color='steelblue')
# plt.yscale("log")
trace.__plot__()
