# %%
from Binaries import *

# %%
Hardware = HardwareClassifier()

for scale in ["1.000", "0.890", "0.500", "0.300", "0.004"]:
    try:
        Hardware.spd_energy_efficiency(f"full_random_traces_downsampled_vem_{scale}")
    except FileNotFoundError:
        Hardware.spd_energy_efficiency(f"random_traces_downsampled_vem_{scale}")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# HardwareClassifier                            full_random_traces_downsampled_vem_1.000  176394       0       0 1827324 -> ACC =   8.80%
# HardwareClassifier                            full_random_traces_downsampled_vem_0.890  183885       0       0 1768269 -> ACC =   9.42%
# HardwareClassifier                            full_random_traces_downsampled_vem_0.500  220603       0       0 1504367 -> ACC =  12.79%
# HardwareClassifier                            random_traces_downsampled_vem_0.300   26261       0       0  121461 -> ACC =  17.78%
# HardwareClassifier                            full_random_traces_downsampled_vem_0.004  246042       0       0      22 -> ACC =  99.99%

# %%
from Binaries import *

ClassicalTriggers = HardwareClassifier()
ClassicalTriggers.spd_energy_efficiency("full_random_traces_downsampled_vem_0.500")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# HardwareClassifier                            full_random_traces_downsampled...    220603       0       0 1504367 -> ACC =  12.79%
