# %%
from Binaries import *

Trigger = HardwareClassifier()
Trigger.energy_efficiency("final_all_triggers", n_points = 10)
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# HardwareClassifier                            final_all_triggers                    89144       0       0  156908 -> ACC =  36.23%
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # OLD (without LPP)

# %%
from Binaries import *

Trigger = HardwareClassifier()
Trigger.energy_efficiency("final_all_triggers")
# Out:
# Classifier                                    Dataset                                  TP      FP      TN      FN
# Fetching predictions for: HardwareClassifier -> final_all_triggers
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# HardwareClassifier                            final_all_triggers                    89144       0       0  156908 -> ACC =  36.23%
