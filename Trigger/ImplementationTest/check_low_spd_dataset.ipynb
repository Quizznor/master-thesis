# %%
from Binaries import *

Events = EventGenerator("/cr/tempdata01/filip/QGSJET-II/LOW_SPD/18.5_19", real_background = False, split = 1)

# %%
Events.physics_test()
# Out:
# Step 4117/4118 | 00:04:43 elapsed ||------------------- || 99% -- 68.954 ms/step, ETA: 00:00:00
# Step 4118/4118 | 00:04:43 elapsed ||--------------------|| 100% -- 68.954 ms/step, ETA: 00:00:00
