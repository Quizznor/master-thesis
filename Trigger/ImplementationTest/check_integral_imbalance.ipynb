# %%
from Binaries import *

TestEvents = EventGenerator("all", split = 1, seed = 41)

# %%
TestEvents.unit_test()
# Out:
# 100.00% - 5.39ms/batch, ETA = 0s ||                      S=S                                           || 6.5235e+16 eV @ 79 m from core
#
# Total time: 280.46s - 97892 traces
# n_signal = 93067, n_background = 4825
# n_injected = 7861 -> 4724.14 Hz background
