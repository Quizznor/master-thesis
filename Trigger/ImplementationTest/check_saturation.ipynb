# %%
from Binaries import *

# %%
Events = EventGenerator(["19_19.5"], split = 1, sigma = 0)

# %%
for i in range(Events.__len__()):

    print(Events.files[i])
    traces, labels = Events.__getitem__(i, full_trace = True)
    print(len(traces))

    for trace in traces: trace.__plot__()

    raise StopIteration
# Out:
# /cr/tempdata01/filip/QGSJET-II/protons/19_19.5/DAT295826_00.csv
# 15
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb Cell 3 in <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(len(traces))
#       <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> for trace in traces: trace.__plot__()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> raise StopIteration
#
# StopIteration:

# %%
from Binaries import *
Example = EventGenerator("all", real_background = True, prior = 0)
# Out:
# [INFO] -- LOADING LO_QUI_DON: randoms1643.csv
# Station not found! THIS SHOULD NOT HAPPEN
# [INFO] -- LOADING LO_QUI_DON: randoms2803.csv
# Station not found! THIS SHOULD NOT HAPPEN

# %%
trace, _ = Example[0].__getitem__(0, full_trace = True)

# %%
trace[0].__plot__()

# %%
from Binaries import *

Events = EventGenerator(["test"], split = 1, sigma = 0)

for i in range(Events.__len__()):

    print(Events.files[i])
    traces, labels = Events.__getitem__(i, full_trace = True)
    print(len(traces))

    for trace in traces: trace.__plot__()

    raise StopIteration
# Out:
# /cr/users/filip/Simulation/TestShowers/DAT295826_00.csv
# /cr/users/filip/Binaries/Signal.py:279: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   yield np.array([signal[station], signal[station + 1], signal[station + 2]])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb Cell 7 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> for i in range(Events.__len__()):
# ...

# %%
print(Events.files)
# Out:
# ['/cr/users/filip/Simulation/TestShowers/DAT295826_00.csv']

# %%
with open('/cr/users/filip/Simulation/TestShowers/DAT295826_00.csv', "r") as test_file:
    lines = test_file.readlines()

# %%
for line in lines:
    print(len(line.split(' ')))
# Out:
# 1043
# 1043
# 1043
# 853
# 853
# 853
# 707
# 707
# 707
# 955
# 955
# 955
# 1033
# 1033
# 1033
# 1312
# 1312
# 1312
# 928
# 928
# 928
# 1103
# 1103
# 1103
# 1076
# 1076
# 1076
# 1312
# 1312
# 98
# 33
# 33
# 158
# 158
# 158
# 42
# 42
# 42
# 251
# 251
# 251
# 370
# 370
# 370
# 650
# 650
# 650
# 32
# 32
# 32
# 438
# 438
# 438
# 413
# 413
# 413
# 646
# 646
# 646
# 28
# 28
# 28
# 28
# 28
# 28
# 281
# 281
# 281
# 521
# 521
# 521
# 34
# 34
# 34
