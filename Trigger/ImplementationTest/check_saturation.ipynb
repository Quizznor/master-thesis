# %%
from Binaries import *

# %%
Events = EventGenerator(["19_19.5"], split = 1, sigma = 0)

# %%
for i in range(Events.__len__()):

    print(Events.files[i])
    traces, labels = Events.__getitem__(i, full_trace = True)
    print(len(traces))

    for trace in traces: trace.__plot__()

    raise StopIteration
# Out:
# /cr/tempdata01/filip/QGSJET-II/protons/19_19.5/DAT295826_00.csv
# 15
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb Cell 3 in <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(len(traces))
#       <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> for trace in traces: trace.__plot__()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> raise StopIteration
#
# StopIteration:

# %%
from Binaries import *
Example = EventGenerator("all", real_background = True, prior = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> Example = EventGenerator("all", real_background = True, prior = 0)
#
# NameError: name 'EventGenerator' is not defined

# %%
trace, _ = Example[0].__getitem__(0, full_trace = True)

# %%
trace[0].__plot__()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bauger/cr/users/filip/Trigger/ImplementationTest/check_saturation.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> trace[0].__plot__()
#
# File ~/Binaries/Signal.py:247, in Trace.__plot__(self)
#     244 x = range(self.length)
#     245 int_sig = np.mean([self.int_1.sum(), self.int_2.sum(), self.int_3.sum()])
# --> 247 plt.title(f"Station #{self.StationID} - {int_sig:.2f} VEM")
#     248 plt.plot(x, self.pmt_1, c = "green", label = f"PMT #1{', downsampled' if self.downsample else ''}", lw = 1)
#     249 plt.plot(x, self.pmt_2, c = "orange", label = f"PMT #2{', downsampled' if self.downsample else ''}", lw = 1)
#
# AttributeError: 'Trace' object has no attribute 'StationID'
