# %%
from Binaries import *

# %%
TestGen = EventGenerator(["19_19.5"], split = 1, force_inject = 0)

trace, _ = TestGen.__getitem__(0, full_trace = True)
trace = trace[0]

trace.__plot__()
# Out:
# {'split': 1, 'force_inject': 0}

# %%
CopyGen = TestGen.copy(force_inject = 2, apply_downsampling = True)

trace_copy, _ = CopyGen.__getitem__(0, full_trace = True)
trace_copy = trace_copy[0]

trace_copy.__plot__()
# Out:
# {'force_inject': 2, 'apply_downsampling': True}
# {'split': 1, 'force_inject': 2, 'apply_downsampling': True}
