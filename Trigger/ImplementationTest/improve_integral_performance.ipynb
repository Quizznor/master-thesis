# %%
from Binaries import *

TestEvents = EventGenerator(["16_16.5"], split = 1, seed = 41)

# %%
TestEvents.unit_test()
# Out:
# 99.90% - 4.16ms/batch, ETA = 0s ||      X                                                             || 1.6098e+16 eV @ 315 m from core
#
# Total time: 4.58s - 1002 traces
# n_signal = 730, n_background = 272
# n_injected = 75 -> 4403.37 Hz background
