# %%
from Binaries import *

TestEvents = EventGenerator(["16_16.5"], split = 1, seed = 41)

# %%
TestEvents.unit_test(1)
# Out:
# 99.99% - 3.01ms/batch, ETA = 0s ||                X                                                   || 2.6511e+16 eV @ 434 m from core
#
# Total time: 48.34s - 15025 traces
# n_signal = 10913, n_background = 4112
# n_injected = 1197 -> 4686.75 Hz background
