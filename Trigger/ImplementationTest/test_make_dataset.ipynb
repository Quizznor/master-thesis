# %%
from Binaries import *

Test = HardwareClassifier()
Dataset = EventGenerator(["19_19.5"], split = 1)

_ = make_dataset(Test, Dataset, "Test")
# Out:
# Fetching batch 407/10301: 3.94% --> (TP, FP) = (5287, 11) ~ 99.79
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/test_make_dataset.ipynb Cell 1 in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/ImplementationTest/test_make_dataset.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> Test = HardwareClassifier()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/ImplementationTest/test_make_dataset.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> Dataset = EventGenerator(["19_19.5"], split = 1)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/ImplementationTest/test_make_dataset.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> _ = make_dataset(Test, Dataset, "Test")
#
# ...

# %%
print(_)
# Out:
# 0.9979681679647816

# %%
Test.spd_energy_efficiency("Test")
# Out:
# DATASET                                                                TP      FP      TN      FN     sum
# HardwareClassifier Test                                                5295    11      177858  42906  226070  -> Acc = 81.02%, TPR = 99.7927%
# (array([], shape=(7, 0), dtype=float64),
#  array([], shape=(7, 0), dtype=float64))
