# %%
from Binaries import *

p1 = EventGenerator("19_19.5", split = 1, real_background = True, apply_downsampling = True, random_phase = 0, seed = 42)
p2 = EventGenerator("19_19.5", split = 1, real_background = True, apply_downsampling = True, random_phase = 1, seed = 42)
p3 = EventGenerator("19_19.5", split = 1, real_background = True, apply_downsampling = True, random_phase = 2, seed = 42)
# Out:
# [INFO] -- LOADING LO_QUI_DON: randoms2214.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2214.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2214.csv

# %%
p1.__getitem__(0)[0].__plot__()
plt.xlim(200, 450)
plt.ylim(-0.1, 2)
# plt.figure()
p2.__getitem__(0)[0].__plot__()
plt.xlim(200, 450)
plt.ylim(-0.1, 2)
# plt.figure()
p3.__getitem__(0)[0].__plot__()
plt.xlim(200, 450)
plt.ylim(-0.1, 2)
# Out:
# (-0.1, 2.0)

# %%
for b1, b2, b3 in zip(p1, p2, p3):
    for t1, t2, t3 in zip(b1, b2, b3):

        t1.__plot__()
        t2.__plot__()
        t3.__plot__()

        plt.xlim(200, 450)
        plt.ylim(-0.1, 2)

        raise StopIteration
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /cr/users/filip/Trigger/ImplementationTest/test_random_phase.ipynb Cell 3 in <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/ImplementationTest/test_random_phase.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for b1, b2, b3 in zip(p1, p2, p3):
#       <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/ImplementationTest/test_random_phase.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     for t1, t2, t3 in zip(b1, b2, b3):
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcrcws02.iap.kit.edu/cr/users/filip/Trigger/ImplementationTest/test_random_phase.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>         t1.__plot__(ls = "--")
# ...
