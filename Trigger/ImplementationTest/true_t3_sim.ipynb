# %%
from Binaries import *

Trigger = HardwareClassifier()

# %%
_ = Trigger.do_t3_simulation("final_all_triggers", 1e5)
# Out:
# Step 100000/100000 | 00:00:27 elapsed ||--------------------|| 100% -- 0.280 ms/step, ETA: 00:00:00

# %%
from Binaries import *

Trigger = HardwareClassifier()

Events = EventGenerator("all", apply_downsampling = True, split = 1, q_peak = np.array([GLOBAL.q_peak_compatibility for _ in range(3)]))
Events.files = Events.files[:int(1/10 * len(Events.files))]
# Events.files = Events.files[:2]

Trigger.do_true_t3_simulation(Events)
# Out:
# [INFO] -- LOADING LO_QUI_DON: randoms2208.csv
# [INFO] -- LOADING LO_QUI_DON: randoms0894.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2410.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2174.csv
# [INFO] -- LOADING LO_QUI_DON: randoms1556.csv
# [INFO] -- LOADING LO_QUI_DON: randoms0546.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2603.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2442.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2444.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2350.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2433.csv
# [INFO] -- LOADING LO_QUI_DON: randoms1979.csv
# [INFO] -- LOADING LO_QUI_DON: randoms0892.csv
# [INFO] -- LOADING LO_QUI_DON: randoms3855.csv
# [INFO] -- LOADING LO_QUI_DON: randoms2959.csv
# [INFO] -- LOADING LO_QUI_DON: randoms1675.csv
# [INFO] -- LOADING LO_QUI_DON: randoms0668.csv
# [INFO] -- LOADING LO_QUI_DON: randoms0455.csv
# [INFO] -- LOADING LO_QUI_DON: randoms3982.csv
# [INFO] -- LOADING LO_QUI_DON: randoms3738.csv
# ...
