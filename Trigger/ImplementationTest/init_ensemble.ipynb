# %%
from Binaries import *

# %%
TestEnsemble = Ensemble("minimal_conv2d_real_background")
TestEnsemble.PRC("validation_data")

# TestEnsemble.ROC("validation_data")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 1, 40, 1)          10
#
#  flatten (Flatten)           (None, 40)                0
#
#  dense (Dense)               (None, 2)                 82
#
# ...
# Total params: 92
# Trainable params: 92
# Non-trainable params: 0
# _________________________________________________________________
#
# ENSEMBLE_minimal_conv2d_real_background: 10 models successfully initiated
#
#
# DATASET                                                                TP      FP      TN      FN     sum
# ENSEMBLES/minimal_conv2d_real_background/ensemble_1/ validation_data   510702  149     739087  4555   1254493 -> Acc = 99.63%, TPR = 99.9708%
# ENSEMBLES/minimal_conv2d_real_background/ensemble_2/ validation_data   511230  261     738671  4331   1254493 -> Acc = 99.63%, TPR = 99.9490%
# ...

# %%
TestClassifier = NNClassifier("minimal_conv2d_cut_1.00VEM")
TestClassifier.spd_energy_efficiency("validation_data")

# %%
TestEnsemble = Ensemble("minimal_conv2d_real_background_1.00VEM")
TestEnsemble.ROC("validation_data")
