# %%
from TriggerStudyBinaries_v4 import *

plt.rcParams['figure.figsize'] = [20, 10]

Test = EventGenerator("all", real_background = True, prior = 0, split = 1)

TestTrace, label = Test.__getitem__(10, full_trace = True)

# %%
for pmt in range(3):
    plt.plot(range(TestTrace[0].length), TestTrace[0].Baseline[pmt])

plt.axhline(0, ls = "--")
