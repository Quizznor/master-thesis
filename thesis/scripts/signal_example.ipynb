# %%
from Binaries import *

Events = EventGenerator("19_19.5", split = 1, real_background = True, sigma = 2, seed = 42)
Traces = Events.__getitem__(0)
example_trace = Traces[6]
# Out:
# [INFO] -- LOADING LO_QUI_DON: randoms2214.csv

# %%
plt.rcParams["figure.figsize"] = [25, 9]
plt.axhline(0, c = "k", ls = "solid", lw = 2)

for i in range(3):
    plt.plot(range(2048), example_trace.Signal[i], label = f"PMT \#{i}", ls = "--")

# plt.ylim(-5, 50)
plt.xlim(500, 1500)
plt.xlabel("Bin / $8.33\,\mathrm{ns}$")
plt.ylabel("Signal strength / $\mathrm{ADC}$")
plt.legend()
