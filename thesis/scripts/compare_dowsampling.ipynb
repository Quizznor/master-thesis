# %%
from Binaries import *

Events = EventGenerator("19_19.5", split = 1, real_background = True, sigma = 2, seed = 42, force_inject = 5)
Traces = Events.__getitem__(0)
Traces[6].__plot__()

plt.savefig("/cr/users/filip/thesis/plots/time_trace_UUB.png")
# Out:
# [INFO] -- LOADING LO_QUI_DON: randoms2214.csv

# %%
from Binaries import *

Events = EventGenerator("19_19.5", split = 1, real_background = True, sigma = 2, seed = 42, apply_downsampling = True, force_inject = 5)
Traces = Events.__getitem__(0)
Traces[6].__plot__()

plt.savefig("/cr/users/filip/thesis/plots/time_trace_UB.png")
# Out:
# [INFO] -- LOADING NURIA: randoms0117.csv
