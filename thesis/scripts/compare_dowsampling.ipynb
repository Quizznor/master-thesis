# %%
from Binaries import *

Events = EventGenerator(["19_19.5"], split = 1, real_background = True, sigma = 2, seed = 42)
Traces = Events.__getitem__(0)
# Out:
# [INFO] -- LOADING NURIA: randoms0117.csv

# %%
Traces[6].__plot__()

# %%
from Binaries import *

Events = EventGenerator(["19_19.5"], split = 1, real_background = True, sigma = 2, seed = 42, apply_downsampling = True)
Traces = Events.__getitem__(0)
Traces[6].__plot__()
# Out:
# [INFO] -- LOADING NURIA: randoms0117.csv
